# %% [markdown]
# # **Observation3**
# ## This observation aims to compare the distribution of verdicts in cases pertaining to Child Labour and if the gender of the petitioner advocate(the one filing the case) plays a influential role or not. I also tried to see if type of case (if the victim being present or giving a statement increased chances of convicting) provides any advantage, however there weren't enough datapoints in these categories so couldn't be done.

# %% [markdown]
# ## **Importing relevant modules and files**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# import matplotlib.pyplot as plt
import plotly.express as px

keys= pd.read_csv("/kaggle/input/keys-precog/act_key.csv")
act_sections=pd.read_csv("/kaggle/input/acts-sections/acts_sections.csv")
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## **Reading case CSVs and concatenating them**

# %%
case=pd.read_csv("/kaggle/input/precog-cases/cases_2010.csv")
for i in range(1,3):
    case_year=pd.read_csv("/kaggle/input/precog-cases/cases_201%s.csv" %i)
    case=pd.concat([case, case_year])

# %% [markdown]
# ## **Getting all ActIDs whose description contains "Child Labour"**

# %%
ActIDs=keys[keys.act_s.str.contains('Child Labour',na=False)][['act_s','act']]
ActIDs
# Out:
#                                                    act_s      act
# 4438     Child Labour (Prohibition and Control) Act 1986   4438.0
# 4439       Child Labour (Prohibition and Regulation) Act   4439.0
# 4440   Child Labour (Prohibition and Regulation) Act ...   4440.0
# 4441   Child Labour (Prohibition and Regulation) Act,...   4441.0
# 4442     Child Labour (Prohibition and Regulation) Rules   4442.0
# 4443   Child Labour (Prohibition and Regultion) Act, ...   4443.0
# 4444    Child Labour (Restriction & Regulation) Act 1986   4444.0
# 4445                               Child Labour ACt 1986   4445.0
# 4446                                    Child Labour Act   4446.0
# 4447                                 Child Labour Act  \   4447.0
# 4448                               Child Labour Act 1986   4448.0
# 4449                                  Child Labour Act \   4449.0
# 4450                                   Child Labour Act.   4450.0
# 4451                     Child Labour Amendment Act 2016   4451.0
# 4452        Child Labour Prevention and Control Act 1986   4452.0
# 4453          Child Labour Prevention and Regulation Act   4453.0
# 4454    Child Labour Prevention and Regulation Act, 1986   4454.0
# 4455             Child Labour Prohibation and Regulation   4455.0
# 4456                        Child Labour Prohibition Act   4456.0
# 4457         Child Labour Prohibition and Regulation Act   4457.0
# 4458    Child Labour Prohibition and Regulation Act 1986   4458.0
# 4459   Child Labour Prohibition and Regulation Act, 1986   4459.0
# 4460    Child Labour prohibition and regulation Act 1986   4460.0
# 17182                          The Child Labour Act 1986  17182.0
# 20441                U/S 3 r/w 14.1. of Child Labour Act  20441.0
# 21233                             U/S.3 Child Labour Act  21233.0
# 23268  U/s 3 of Child Labour  Act Prohibition and Con...  23268.0
# 29031                 u/sec 3 R/W 14 of Child Labour Act  29031.0
# 29243  u/sec. 366(A),370(A), 373,420 R/w 34 of IPC,  ...  29243.0

# %% [markdown]
# ## **Finding all CaseIDs that include this Act**

# %%
CaseIDs=act_sections[act_sections.act.isin(ActIDs.act)][['ddl_case_id','act']]
CaseIDs
# Out:
#                        ddl_case_id     act
# 4850505   13-06-03-205800104282014  4439.0
# 4851792   22-10-05-203900000782018  4439.0
# 4851793   22-10-05-203900000562019  4439.0
# 4851794   22-10-05-203900000772018  4439.0
# 4851795   22-10-05-203900000572019  4439.0
# ...                            ...     ...
# 76560476  22-11-06-203900000332018  4439.0
# 76562370  11-05-05-224600000262015  4439.0
# 76768008  03-02-14-201200005812012  4457.0
# 76777723  03-02-14-201200003222010  4457.0
# 76789059  26-07-02-202400119482017  4446.0
#
# [6505 rows x 2 columns]

# %% [markdown]
# ## **Reading Disposition id vs Disposition name file**
# ### Selecting the relevant columns and trucating to the head of document (since there are 51 possible verdicts)

# %%
disp_name=pd.read_csv("/kaggle/input/keys-precog/disp_name_key.csv")
disp_name=disp_name[['disp_name','disp_name_s']]
disp_name=disp_name.head(51)
disp_name
# Out:
#     disp_name              disp_name_s
# 0           1                 258 crpc
# 1           2                   abated
# 2           3                absconded
# 3           4                acquitted
# 4           5                  allowed
# 5           6          appeal accepted
# 6           7                    award
# 7           8             bail granted
# 8           9             bail refused
# 9          10            bail rejected
# 10         11                cancelled
# 11         12                   closed
# 12         13                committed
# 13         14               compounded
# 14         15               compromise
# 15         16               confession
# 16         17          contest-allowed
# 17         18                converted
# 18         19                convicted
# 19         20                  decided
# 20         21                     died
# 21         22                dismissed
# 22         23   disposal in lok adalat
# 23         24                 disposed
# 24         25       disposed-otherwise
# 25         26  disposition var missing
# 26         27                 ex-parte
# 27         28                execution
# 28         29                     fine
# 29         30                judgement
# 30         31                not press
# 31         32                    other
# 32         33                otherwise
# 33         34             p.o. consign
# 34         35           partly decreed
# 35         36          plea bargaining
# 36         37             plead guilty
# 37         38                   prison
# 38         39                probation
# 39         40               procedural
# 40         41                    quash
# 41         42   referred to lok adalat
# 42         43                   reject
# 43         44                 remanded
# 44         45                  settled
# 45         46                 sine die
# 46         47                   stayed
# 47         48              transferred
# 48         49              uncontested
# 49         50                  untrace
# 50         51                withdrawn

# %% [markdown]
# ## **Taking all cases on child labour and getting their corresponding dispositions**

# %%
cases=case[case.ddl_case_id.isin(CaseIDs.ddl_case_id)][['ddl_case_id','disp_name']]
#dropping disp_var_missing
cases = cases[cases.disp_name != 26]
cases
# Out:
#                       ddl_case_id  disp_name
# 502168   01-23-15-200305001922010         32
# 502171   01-23-15-200305001952010         24
# 1028187  03-02-14-201200003222010         19
# 1547653  04-04-05-202905003832010         12
# 1577581  04-05-34-202900008852010          4
# ...                           ...        ...
# 6178949  26-08-02-202102946072016         14
# 6205947  26-10-02-202120361772016         19
# 6211695  26-11-02-202100896322016         34
# 6211863  26-11-02-202100921062016         37
# 6211942  26-11-02-202100935602016          4
#
# [560 rows x 2 columns]

# %% [markdown]
# ## **Grouping by dispositions to obtain frequency of each verdict**

# %%
frequencies = cases.groupby('disp_name').count()
# frequencies = cases.groupby(['disp_name']).agg({'ddl_case_id': ['sum']})
frequencies=frequencies.rename(columns={'ddl_case_id': 'freq'})
frequencies = frequencies.reset_index()
display(frequencies)
# Out:
#     disp_name  freq
# 0           1     2
# 1           2     4
# 2           3    26
# 3           4   105
# 4           5    13
# 5           7     3
# 6          11     1
# 7          12     1
# 8          13     1
# 9          14     1
# 10         15     3
# 11         16    14
# 12         18     1
# 13         19    80
# 14         20     2
# 15         22    84
# 16         23    68
# 17         24    19
# 18         25     1
# 19         29    39
# 20         30     8
# 21         32    12
# 22         33     3
# 23         34     4
# 24         36     1
# 25         37     7
# 26         39    12
# 27         40     9
# 28         42     6
# 29         43     2
# 30         46     2
# 31         48    23
# 32         51     3

# %% [markdown]
# ## Final frequency of each verdict

# %%
#merging
frequencies=frequencies.merge(disp_name, on='disp_name')
#select needed columns
frequencies=frequencies[['disp_name_s','freq']]
frequencies
# Out:
#                disp_name_s  freq
# 0                 258 crpc     2
# 1                   abated     4
# 2                absconded    26
# 3                acquitted   105
# 4                  allowed    13
# 5                    award     3
# 6                cancelled     1
# 7                   closed     1
# 8                committed     1
# 9               compounded     1
# 10              compromise     3
# 11              confession    14
# 12               converted     1
# 13               convicted    80
# 14                 decided     2
# 15               dismissed    84
# 16  disposal in lok adalat    68
# 17                disposed    19
# 18      disposed-otherwise     1
# 19                    fine    39
# 20               judgement     8
# 21                   other    12
# 22               otherwise     3
# 23            p.o. consign     4
# 24         plea bargaining     1
# 25            plead guilty     7
# 26               probation    12
# 27              procedural     9
# 28  referred to lok adalat     6
# 29                  reject     2
# 30                sine die     2
# 31             transferred    23
# 32               withdrawn     3

# %% [markdown]
# ## **Plotting frequency of each verdict**

# %%
fig = px.bar(frequencies, x = 'disp_name_s', y = 'freq',title='verdict vs frequency')
fig.show()
# Out:
# <div>                            <div id="82dd7faf-0ea5-4e2f-a9ba-cde538da92f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82dd7faf-0ea5-4e2f-a9ba-cde538da92f5")) {                    Plotly.newPlot(                        "82dd7faf-0ea5-4e2f-a9ba-cde538da92f5",                        [{"alignmentgroup":"True","hovertemplate":"disp_name_s=%{x}<br>freq=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["258 crpc","abated","absconded","acquitted","allowed","award","cancelled","closed","committed","compounded","compromise","confession","converted","convicted","decided","dismissed","disposal in lok adalat","disposed","disposed-otherwise","fine","judgement","other","otherwise","p.o. consign","plea bargaining","plead guilty","probation","procedural","referred to lok adalat","reject","sine die","transferred","withdrawn"],"xaxis":"x","y":[2,4,26,105,13,3,1,1,1,1,3,14,1,80,2,84,68,19,1,39,8,12,3,4,1,7,12,9,6,2,2,23,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0, ...

# %% [markdown]
# ## **Conclusion** : Maximum number of cases were acquitted/ dismissed, which highlights the sad state of affairs. While filing a case, a petitioner would have sufficient proof of the Defendant being repsponsible for some form of child labour. Acquittal or Dismissal shows how these cases are often neglected.

# %% [markdown]
# ## **Seeing how the verdict changes based on gender of petitioner advocate**
# ### Intial plan was to observe this bias through the gender of the judge, but there weren't enough datapoints as mentioned earlier. The motivation here was to observe any kind of bias which might exist related to gender.

# %% [markdown]
# ## Extracting relevant columns from the case database into a new dataframe

# %%
cases=case[case.ddl_case_id.isin(CaseIDs.ddl_case_id)][['ddl_case_id','female_adv_pet','disp_name']]
#dropping disp_var_missing
cases = cases[cases.disp_name != 26]
cases
# Out:
#                       ddl_case_id  female_adv_pet  disp_name
# 502168   01-23-15-200305001922010           -9999         32
# 502171   01-23-15-200305001952010           -9999         24
# 1028187  03-02-14-201200003222010           -9998         19
# 1547653  04-04-05-202905003832010           -9999         12
# 1577581  04-05-34-202900008852010           -9999          4
# ...                           ...             ...        ...
# 6178949  26-08-02-202102946072016           -9999         14
# 6205947  26-10-02-202120361772016           -9999         19
# 6211695  26-11-02-202100896322016           -9999         34
# 6211863  26-11-02-202100921062016           -9999         37
# 6211942  26-11-02-202100935602016           -9999          4
#
# [560 rows x 3 columns]

# %% [markdown]
# ## Initialising a dict to store 3 different dataframes for 3 different categories-- males, females and unknown

# %%
dict={}
dict['undef']=cases[(cases.female_adv_pet==-9999) | (cases.female_adv_pet==-9998)][['ddl_case_id','disp_name']]
dict['males']=cases[(cases.female_adv_pet==0)][['ddl_case_id','disp_name']]
dict['females']=cases[(cases.female_adv_pet==1)][['ddl_case_id','disp_name']]

# %% [markdown]
# ## Defining a function to modify the dataframes following the same steps as above

# %%
def for_plotting(string):
    # grouping by the disposition name
    dict[string]= dict[string].groupby('disp_name').count()
    # renaming column and resetting index after grouping and to handle multi-index
    dict[string]=dict[string].rename(columns={'ddl_case_id': 'freq'})
    dict[string] = dict[string].reset_index()
    # merging with disp_name and choosing relevant columns to obtain name instead of codes
    dict[string]=dict[string].merge(disp_name, on='disp_name')
    dict[string]=dict[string][['disp_name_s','freq']]

# %% [markdown]
# ## Calling the above function for the 3 dataframes

# %%
for_plotting('undef')
for_plotting('males')
for_plotting('females')

# %% [markdown]
# ## Plotting all 3 in one graph for comparison

# %%
#alternative code for plotting
import plotly.graph_objects as go

f1 = go.Figure(
    data = [
        go.Bar(x=dict['undef']['disp_name_s'], y=dict['undef']['freq'], name="undef"),
        go.Bar(x=dict['males']['disp_name_s'], y=dict['males']['freq'], name="males"),
        go.Bar(x=dict['females']['disp_name_s'], y=dict['females']['freq'], name="females"),
    ],
    layout = {"xaxis": {"title": "verdicts"}, "yaxis": {"title": "frequency"}, "title": "verdict vs frequency of judges"}
)
f1
# Out:
# <div>                            <div id="707a5f44-203a-446a-82ec-465f826bcc36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("707a5f44-203a-446a-82ec-465f826bcc36")) {                    Plotly.newPlot(                        "707a5f44-203a-446a-82ec-465f826bcc36",                        [{"name":"undef","x":["258 crpc","abated","absconded","acquitted","allowed","award","cancelled","closed","committed","compounded","compromise","confession","converted","convicted","decided","dismissed","disposal in lok adalat","disposed","disposed-otherwise","fine","judgement","other","otherwise","p.o. consign","plea bargaining","plead guilty","probation","procedural","referred to lok adalat","reject","sine die","transferred","withdrawn"],"y":[2,3,23,84,11,2,1,1,1,1,3,14,1,68,1,79,64,15,1,37,6,11,3,4,1,7,5,8,4,2,1,22,1],"type":"bar"},{"name":"males","x":["abated","absconded","acquitted","allowed","convicted","decided","dismissed","disposed","fine","judgement","other","probation","procedural","referred to lok adalat","sine die","withdrawn"],"y":[1,3,20,2,9,1,3,4,2,2,1,7,1,2,1,1],"type":"bar"},{"name":"females","x":["acquitted","award","convicted","dismissed","disposal in lok adalat","transferred","withdrawn"],"y":[1,1,3,2,4,1,1],"type":"bar"}],                        {"title":{"text":"verdict vs frequency of judges"},"xaxis":{"title":{"text":"verdicts"}},"yaxis":{"title":{"text":"frequency"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %% [markdown]
# ### Clear takeaways from this plot:
# 1. The number of undefined entries is much larger than males of females showing problems with data(missing names) and the neural network used for name segregation(unknown gender)
# 2. after acquitted, convicted is the more frequent than dismissal in the case of male petitioners

# %% [markdown]
# ## Plotting all categories one at a time for comparison within categories

# %% [markdown]
# ## Females

# %%
f1 = go.Figure(
    data = [
        go.Bar(x=dict['females']['disp_name_s'], y=dict['females']['freq'], name="females"),
    ],
    layout = {"xaxis": {"title": "verdicts"}, "yaxis": {"title": "frequency"}, "title": "verdict vs frequency of judges"}
)
f1
# Out:
# <div>                            <div id="816b88b6-6d41-4a6c-bee4-445e762a7c07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("816b88b6-6d41-4a6c-bee4-445e762a7c07")) {                    Plotly.newPlot(                        "816b88b6-6d41-4a6c-bee4-445e762a7c07",                        [{"name":"females","x":["acquitted","award","convicted","dismissed","disposal in lok adalat","transferred","withdrawn"],"y":[1,1,3,2,4,1,1],"type":"bar"}],                        {"title":{"text":"verdict vs frequency of judges"},"xaxis":{"title":{"text":"verdicts"}},"yaxis":{"title":{"text":"frequency"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pa ...
#
# var gd = document.getElementById('816b88b6-6d41-4a6c-bee4-445e762a7c07');
# var x = new MutationObserver(function (mutations, observer) {

# %% [markdown]
# ## Unknown

# %%
f1 = go.Figure(
    data = [
        go.Bar(x=dict['undef']['disp_name_s'], y=dict['undef']['freq'], name="undef"),
#         go.Bar(x=dict['males']['disp_name_s'], y=dict['males']['freq'], name="males"),
#         go.Bar(x=dict['females']['disp_name_s'], y=dict['females']['freq'], name="females"),
    ],
    layout = {"xaxis": {"title": "verdicts"}, "yaxis": {"title": "frequency"}, "title": "verdict vs frequency of judges"}
)
f1
# Out:
# <div>                            <div id="0f0742a6-ed4e-479c-9606-a1e02d6f2351" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f0742a6-ed4e-479c-9606-a1e02d6f2351")) {                    Plotly.newPlot(                        "0f0742a6-ed4e-479c-9606-a1e02d6f2351",                        [{"name":"undef","x":["258 crpc","abated","absconded","acquitted","allowed","award","cancelled","closed","committed","compounded","compromise","confession","converted","convicted","decided","dismissed","disposal in lok adalat","disposed","disposed-otherwise","fine","judgement","other","otherwise","p.o. consign","plea bargaining","plead guilty","probation","procedural","referred to lok adalat","reject","sine die","transferred","withdrawn"],"y":[2,3,23,84,11,2,1,1,1,1,3,14,1,68,1,79,64,15,1,37,6,11,3,4,1,7,5,8,4,2,1,22,1],"type":"bar"}],                        {"title":{"text":"verdict vs frequency of judges"},"xaxis":{"title":{"text":"verdicts"}},"yaxis":{"title":{"text":"frequency"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error ...

# %% [markdown]
# ## Males

# %%
f1 = go.Figure(
    data = [
#         go.Bar(x=dict['undef']['disp_name_s'], y=dict['undef']['freq'], name="undef"),
        go.Bar(x=dict['males']['disp_name_s'], y=dict['males']['freq'], name="males"),
#         go.Bar(x=dict['females']['disp_name_s'], y=dict['females']['freq'], name="females"),
    ],
    layout = {"xaxis": {"title": "verdicts"}, "yaxis": {"title": "frequency"}, "title": "verdict vs frequency of judges"}
)
f1
# Out:
# <div>                            <div id="a5689c34-ce2b-465e-b2f4-8d9572339136" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5689c34-ce2b-465e-b2f4-8d9572339136")) {                    Plotly.newPlot(                        "a5689c34-ce2b-465e-b2f4-8d9572339136",                        [{"name":"males","x":["abated","absconded","acquitted","allowed","convicted","decided","dismissed","disposed","fine","judgement","other","probation","procedural","referred to lok adalat","sine die","withdrawn"],"y":[1,3,20,2,9,1,3,4,2,2,1,7,1,2,1,1],"type":"bar"}],                        {"title":{"text":"verdict vs frequency of judges"},"xaxis":{"title":{"text":"verdicts"}},"yaxis":{"title":{"text":"frequency"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpo ...
#
# var gd = document.getElem

# %% [markdown]
# ### Surprisingly, more male petitioners had their accused acquitted than in females, However this could be due to a huge gap of the number in each category as well.
# ### The unknown category has comparable numbers for dismissed, acquitted, and convicted. The first 2 still dominating showing the neglect these cases receive.
